# %%
import sys
import pandas as pd

print(sys.executable)
# Out:
# c:\Users\SHREEJA\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install -U datasets

# %%
from datasets import load_dataset

dataset = load_dataset(
    "theatticusproject/cuad",
    verification_mode="no_checks"
)

print(dataset)
# Out:
# Resolving data files:   0%|          | 0/714 [00:00<?, ?it/s]
# ...
# DatasetDict({
#     train: Dataset({
#         features: ['pdf'],
#         num_rows: 511
#     })
# })

# %%
train_data = dataset["train"]

print(train_data.column_names)
# Out:
# ['pdf']

# %%
import sys
# !{sys.executable} -m pip install pdfplumber

# %%
sample = train_data[0]

print(sample.keys())
# Out:
# dict_keys(['pdf'])

# %%
sample
# Out:
# {'pdf': <pdfplumber.pdf.PDF at 0x1ab118682f0>}

# %%
train_data = dataset["train"]

print("Number of samples:", len(train_data))
print("\nColumns:")
print(train_data.column_names)
# Out:
# Number of samples: 511
#
# Columns:
# ['pdf']

# %%
for key, value in sample.items():
    print("=" * 50)
    print("COLUMN:", key)
    print("TYPE:", type(value))
    print("VALUE:")
    print(str(value)[:500])
    print()
# Out:
# ...
# COLUMN: pdf
# TYPE: <class 'pdfplumber.pdf.PDF'>
# VALUE:
# ...

# %%
for i in range(3):
    print("\n")
    print("=" * 80)
    print("SAMPLE", i)
    print("=" * 80)

    for key, value in train_data[i].items():
        print(f"\n{key}:")
        print(str(value)[:300])
# Out:
# ...
# SAMPLE 0
# ...
#
# pdf:
# ...
#
#
# ...
# SAMPLE 1
# ...
#
# pdf:
# ...
#
#
# ...
# SAMPLE 2
# ...
#
# pdf:
# ...

# %%
df = pd.DataFrame(train_data[:10])

df.head()
# Out:
#                                                  pdf
# 0  <pdfplumber.pdf.PDF object at 0x000001AB11973A80>
# 1  <pdfplumber.pdf.PDF object at 0x000001AB119F6C30>
# 2  <pdfplumber.pdf.PDF object at 0x000001AB12090050>
# 3  <pdfplumber.pdf.PDF object at 0x000001AB12090490>
# 4  <pdfplumber.pdf.PDF object at 0x000001AB119B3950>

# %%
df = pd.DataFrame(train_data[:10])

df.head()
# Out:
#                                                  pdf
# 0  <pdfplumber.pdf.PDF object at 0x000001AB12084120>
# 1  <pdfplumber.pdf.PDF object at 0x000001AB11863E90>
# 2  <pdfplumber.pdf.PDF object at 0x000001AB12088290>
# 3  <pdfplumber.pdf.PDF object at 0x000001AB11A2FCD0>
# 4  <pdfplumber.pdf.PDF object at 0x000001AB120B8100>

# %%
with open("dataset_notes.txt", "w", encoding="utf-8") as f:
    f.write(f"Total Samples: {len(train_data)}\n")
    f.write(f"Columns: {train_data.column_names}\n")

print("Notes saved successfully.")
# Out:
# Notes saved successfully.

# %%
from datasets import load_dataset

dataset = load_dataset(
    "theatticusproject/cuad",
    verification_mode="no_checks"
)

print(dataset)
# Out:
# ...
# Resolving data files:   0%|          | 0/714 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['pdf'],
#         num_rows: 511
#     })
# })
